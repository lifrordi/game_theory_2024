# %%
import matplotlib.pyplot as plt
import numpy as np

import efg
import week6
import week8
import week9

# %%
np.set_printoptions(precision=5)

# %%
# In all examples, all CFR variants are initialized using uniform strategies
# You can compare the final strategies with optimal strategies listed on Wikipedia
# https://en.wikipedia.org/wiki/Kuhn_poker
kuhn_poker = efg.KuhnPoker()

strategies = week8.cfr(kuhn_poker, epochs=1000)
exploitability_values = week6.plot_exploitability(kuhn_poker, strategies, 'CFR')
print(f'Final exploitability value of CFR: {exploitability_values[-1]:.5f}', end='\n\n')

strategies = week9.cfr_br(kuhn_poker, epochs=1000)
exploitability_values = week6.plot_exploitability(kuhn_poker, strategies, 'CFR-BR')
print(f'Final exploitability value of CFR-BR: {exploitability_values[-1]:.5f}', end='\n\n')

strategies = week9.cfr_plus(kuhn_poker, epochs=1000)
exploitability_values = week6.plot_exploitability(kuhn_poker, strategies, 'CFR+')
print(f'Final exploitability value of CFR+: {exploitability_values[-1]:.5f}', end='\n\n')

plt.legend()
plt.show()
# Out:
# Final strategy for Player 1 when naive=False:
# ('J',):
#   Check: 0.79919
#   Bet: 0.20081
# ('J', 'Check', 'Bet'):
#   Call: 0.00031
#   Fold: 0.99969
# ('Q',):
#   Check: 0.99655
#   Bet: 0.00345
# ('Q', 'Check', 'Bet'):
#   Call: 0.56746
#   Fold: 0.43254
# ('K',):
#   Check: 0.40113
#   Bet: 0.59887
# ('K', 'Check', 'Bet'):
#   Call: 0.99938
#   Fold: 0.00062
#
# Final strategy for Player 2 when naive=False:
# ('Q', 'Check'):
#   Check: 0.99623
#   Bet: 0.00377
# ('Q', 'Bet'):
#   Call: 0.36900
#   Fold: 0.63100
# ('K', 'Check'):
#   Check: 0.00050
#   Bet: 0.99950
# ('K', 'Bet'):
#   Call: 0.99950
#   Fold: 0.00050
# ('J', 'Check'):
#   Check: 0.67264
#   Bet: 0.32736
# ('J', 'Bet'):
#   Call: 0.00050
#   Fold: 0.99950
#
# Utility of Player 1 and Player 2 when playing their final strategies: [-0.05556  0.05556]
# Final exploitability value of CFR: 0.00723
#
# Final strategy for Player 1:
# ('J',):
#   Check: 0.80623
#   Bet: 0.19377
# ('J', 'Check', 'Bet'):
#   Call: 0.00031
#   Fold: 0.99969
# ('Q',):
#   Check: 0.99563
#   Bet: 0.00437
# ('Q', 'Check', 'Bet'):
#   Call: 0.54465
#   Fold: 0.45535
# ('K',):
#   Check: 0.38108
#   Bet: 0.61892
# ('K', 'Check', 'Bet'):
#   Call: 0.99934
#   Fold: 0.00066
#
# Final strategy for Player 2:
# ('Q', 'Check'):
#   Check: 0.99650
#   Bet: 0.00350
# ('Q', 'Bet'):
#   Call: 0.36114
#   Fold: 0.63886
# ('K', 'Check'):
#   Check: 0.00050
#   Bet: 0.99950
# ('K', 'Bet'):
#   Call: 0.99950
#   Fold: 0.00050
# ('J', 'Check'):
#   Check: 0.68581
#   Bet: 0.31419
# ('J', 'Bet'):
#   Call: 0.00050
#   Fold: 0.99950
#
# Utility of Player 1 and Player 2 when playing their final strategies: [-0.05539  0.05539]
# Final exploitability value of CFR-BR: 0.00720
#
# Final strategy for Player 1:
# ('J',):
#   Check: 0.78340
#   Bet: 0.21660
# ('J', 'Check', 'Bet'):
#   Call: 0.00000
#   Fold: 1.00000
# ('Q',):
#   Check: 0.99998
#   Bet: 0.00002
# ('Q', 'Check', 'Bet'):
#   Call: 0.55049
#   Fold: 0.44951
# ('K',):
#   Check: 0.34863
#   Bet: 0.65137
# ('K', 'Check', 'Bet'):
#   Call: 1.00000
#   Fold: 0.00000
#
# Final strategy for Player 2:
# ('Q', 'Check'):
#   Check: 0.99999
#   Bet: 0.00001
# ('Q', 'Bet'):
#   Call: 0.33326
#   Fold: 0.66674
# ('K', 'Check'):
#   Check: 0.00000
#   Bet: 1.00000
# ('K', 'Bet'):
#   Call: 1.00000
#   Fold: 0.00000
# ('J', 'Check'):
#   Check: 0.66676
#   Bet: 0.33324
# ('J', 'Bet'):
#   Call: 0.00000
#   Fold: 1.00000
#
# Utility of Player 1 and Player 2 when playing their final strategies: [-0.05556  0.05556]
# Final exploitability value of CFR+: 0.00007

# %%
# This implements the Poker-like game tree presented in the lecture
lecture_poker = efg.LecturePoker()

strategies = week8.cfr(lecture_poker, epochs=500)
exploitability_values = week6.plot_exploitability(lecture_poker, strategies, 'CFR')
print(f'Final exploitability value of CFR: {exploitability_values[-1]:.5f}', end='\n\n')

strategies = week9.cfr_br(lecture_poker, epochs=500)
exploitability_values = week6.plot_exploitability(lecture_poker, strategies, 'CFR-BR')
print(f'Final exploitability value of CFR-BR: {exploitability_values[-1]:.5f}', end='\n\n')

strategies = week9.cfr_plus(lecture_poker, epochs=500)
exploitability_values = week6.plot_exploitability(lecture_poker, strategies, 'CFR+')
print(f'Final exploitability value of CFR+: {exploitability_values[-1]:.5f}', end='\n\n')

plt.legend()
plt.show()
# Out:
# Final strategy for Player 1 when naive=False:
# ('K',):
#   Check: 0.99638
#   Bet: 0.00362
# ('K', 'Check', 'Bet'):
#   Call: 0.50992
#   Fold: 0.49008
# ('A',):
#   Check: 0.99230
#   Bet: 0.00770
# ('A', 'Check', 'Bet'):
#   Call: 0.99950
#   Fold: 0.00050
#
# Final strategy for Player 2 when naive=False:
# ('K', 'Check'):
#   Check: 0.47174
#   Bet: 0.52826
# ('K', 'Bet'):
#   Call: 0.00100
#   Fold: 0.99900
# ('A', 'Check'):
#   Check: 0.00100
#   Bet: 0.99900
# ('A', 'Bet'):
#   Call: 0.99900
#   Fold: 0.00100
#
# Utility of Player 1 and Player 2 when playing their final strategies: [-0.1281  0.1281]
# Final exploitability value of CFR: 0.00615
#
# Final strategy for Player 1:
# ('K',):
#   Check: 0.99638
#   Bet: 0.00362
# ('K', 'Check', 'Bet'):
#   Call: 0.47910
#   Fold: 0.52090
# ('A',):
#   Check: 0.99230
#   Bet: 0.00770
# ('A', 'Check', 'Bet'):
#   Call: 0.99950
#   Fold: 0.00050
#
# Final strategy for Player 2:
# ('K', 'Check'):
#   Check: 0.48603
#   Bet: 0.51397
# ('K', 'Bet'):
#   Call: 0.00100
#   Fold: 0.99900
# ('A', 'Check'):
#   Check: 0.00100
#   Bet: 0.99900
# ('A', 'Bet'):
#   Call: 0.99900
#   Fold: 0.00100
#
# Utility of Player 1 and Player 2 when playing their final strategies: [-0.12837  0.12837]
# Final exploitability value of CFR-BR: 0.00655
#
# Final strategy for Player 1:
# ('K',):
#   Check: 0.99998
#   Bet: 0.00002
# ('K', 'Check', 'Bet'):
#   Call: 0.49565
#   Fold: 0.50435
# ('A',):
#   Check: 0.99991
#   Bet: 0.00009
# ('A', 'Check', 'Bet'):
#   Call: 1.00000
#   Fold: 0.00000
#
# Final strategy for Player 2:
# ('K', 'Check'):
#   Check: 0.49961
#   Bet: 0.50039
# ('K', 'Bet'):
#   Call: 0.00000
#   Fold: 1.00000
# ('A', 'Check'):
#   Check: 0.00001
#   Bet: 0.99999
# ('A', 'Bet'):
#   Call: 1.00000
#   Fold: 0.00000
#
# Utility of Player 1 and Player 2 when playing their final strategies: [-0.12503  0.12503]
# Final exploitability value of CFR+: 0.00061

# %%
# This is a sequential version of Rock Paper Scissors where
# the second player *can* observe actions of the first player
rock_paper_scissors = efg.RockPaperScissors()

strategies = week8.cfr(rock_paper_scissors, epochs=250)
exploitability_values = week6.plot_exploitability(rock_paper_scissors, strategies, 'CFR')
print(f'Final exploitability value of CFR: {exploitability_values[-1]:.5f}', end='\n\n')

strategies = week9.cfr_br(rock_paper_scissors, epochs=250)
exploitability_values = week6.plot_exploitability(rock_paper_scissors, strategies, 'CFR-BR')
print(f'Final exploitability value of CFR-BR: {exploitability_values[-1]:.5f}', end='\n\n')

strategies = week9.cfr_plus(rock_paper_scissors, epochs=250)
exploitability_values = week6.plot_exploitability(rock_paper_scissors, strategies, 'CFR+')
print(f'Final exploitability value of CFR+: {exploitability_values[-1]:.5f}', end='\n\n')

plt.legend()
plt.show()
# Out:
# Final strategy for Player 1 when naive=False:
# ():
#   R: 0.00133
#   P: 0.99734
#   S: 0.00133
#
# Final strategy for Player 2 when naive=False:
# ('R',):
#   R: 0.00133
#   P: 0.99734
#   S: 0.00133
# ('P',):
#   R: 0.00133
#   P: 0.00133
#   S: 0.99734
# ('S',):
#   R: 0.99734
#   P: 0.00133
#   S: 0.00133
#
# Utility of Player 1 and Player 2 when playing their final strategies: [-0.99602  0.99602]
# Final exploitability value of CFR: 0.00199
#
# Final strategy for Player 1:
# ():
#   R: 0.00133
#   P: 0.99734
#   S: 0.00133
#
# Final strategy for Player 2:
# ('R',):
#   R: 0.00133
#   P: 0.99734
#   S: 0.00133
# ('P',):
#   R: 0.00133
#   P: 0.00133
#   S: 0.99734
# ('S',):
#   R: 0.99734
#   P: 0.00133
#   S: 0.00133
#
# Utility of Player 1 and Player 2 when playing their final strategies: [-0.99602  0.99602]
# Final exploitability value of CFR-BR: 0.00199
#
# Final strategy for Player 1:
# ():
#   R: 0.49996
#   P: 0.00007
#   S: 0.49996
#
# Final strategy for Player 2:
# ('R',):
#   R: 0.00003
#   P: 0.99994
#   S: 0.00003
# ('P',):
#   R: 0.00001
#   P: 0.00001
#   S: 0.99998
# ('S',):
#   R: 0.99994
#   P: 0.00003
#   S: 0.00003
#
# Utility of Player 1 and Player 2 when playing their final strategies: [-0.99991  0.99991]
# Final exploitability value of CFR+: 0.00005
